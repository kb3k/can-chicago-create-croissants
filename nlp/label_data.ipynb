# %%
import pandas as pd

# %%
df = pd.read_csv("unlabeled_df.csv", index_col='idx')

# %%
df.head()
# Out:
#                            BakeryName  \
# idx
# idx0  hendrickx belgian bread crafter
# idx1               lost larson bakery
# idx2       bang bang pie and biscuits
# idx3                      good ambler
# idx4          p%C3%A2tisserie coralie
#
#                                                  Review  \
# idx
# idx0  The almond chocolate croissant and french coun...
# idx1  These are the best cinnamon rolls ever. The cr...
# idx2  reminded me of a croissant) and light. The act...
# idx3  minutes. - Ham and cheese croissant: croissant...
# idx4  is a croissant desert. Search no more. Very fr...
#
#                                          Review_Prepped  \
# idx
# idx0  ['almond', 'chocol', 'croissant', 'french', 'c...
# idx1  ['best', 'cinnamon', 'roll', 'ever', 'croissan...
# idx2  ['remind', 'croissant', 'light', 'actual', 'fi...
# idx3  ['minut', 'ham', 'chees', 'croissant', ':', 'c...
# idx4  ['croissant', 'desert', 'search', 'friend', 's...
#
#                                      Review_Prepped_str  \
# idx
# idx0  almond chocol croissant french countri bread q...
# idx1  best cinnamon roll ever croissant also delici ...
# idx2  remind croissant light actual fill good clear ...
# idx3  minut ham chees croissant : croissant super fl...
# idx4  croissant desert search friend staff great tea...
#
#                                       word_count  label
# idx
# idx0  <FreqDist with 10 samples and 10 outcomes>    NaN
# idx1    <FreqDist with 9 samples and 9 outcomes>    NaN
# idx2    <FreqDist with 8 samples and 8 outcomes>    NaN
# idx3  <FreqDist with 11 samples and 12 outcomes>    NaN
# idx4  <FreqDist with 14 samples and 14 outcomes>    NaN

# %%
df.loc[(df.Review_Prepped_str.str.contains('flak')) & (df.BakeryName!='hoosier mama pie company'), 'label'] = 'artisan'

# %%
df[df.label=='artisan']
# Out:
#                                               BakeryName  \
# idx
# idx3                                         good ambler
# idx27                          plein air cafe and eatery
# idx33                                       caffe umbria
# idx39  abc bakery and deli norridge?hrid=SDxAypM6Hgjz...
#
#                                                   Review  \
# idx
# idx3   minutes. - Ham and cheese croissant: croissant...
# idx27  for more. Pistachio Hazelnut Danish - 4.5/5. F...
# idx33  are the highlight of the show, you absolutely ...
# idx39  of the seductive sweets. I chose a nutella cro...
#
#                                           Review_Prepped  \
# idx
# idx3   ['minut', 'ham', 'chees', 'croissant', ':', 'c...
# idx27  ['pistachio', 'hazelnut', 'danish', '4', '5', ...
# idx33  ['highlight', 'show', 'absolut', 'get', 'crois...
# idx39  ['seduct', 'sweet', 'chose', 'nutella', 'crois...
#
#                                       Review_Prepped_str  \
# idx
# idx3   minut ham chees croissant : croissant super fl...
# idx27  pistachio hazelnut danish 4 5 5 flaki croissan...
# idx33  highlight show absolut get croissant flaki but...
# idx39  seduct sweet chose nutella croissant fluffi fl...
#
#                                        word_count    label
# idx
# idx3   <FreqDist with 11 samples and 12 outcomes>  artisan
# idx27  <FreqDist with 12 samples and 13 outcomes>  artisan
# idx33  <FreqDist with 12 samples and 12 outcomes>  artisan
# idx39  <FreqDist with 12 samples and 12 outcomes>  artisan

# %%
# may need sentiment analysis first to determine whether positive or negative; then apply the paris / france 
# american loc

# %%
pd.options.display.max_colwidth = None
df.loc[(df.Review_Prepped_str.str.contains('paris'))] # jk p obv and only 1
# Out:
#                   BakeryName  \
# idx
# idx10  pilot project brewing
#
#                                                                                                         Review  \
# idx
# idx10  Parisian Rose latte (with pretty rose petals on top - highly recommend!) and chocolate croissant. My”\n
#
#                                                                                                    Review_Prepped  \
# idx
# idx10  ['parisian', 'rose', 'latt', 'pretti', 'rose', 'petal', 'top', 'high', 'recommend', 'chocol', 'croissant']
#
#                                                              Review_Prepped_str  \
# idx
# idx10  parisian rose latt pretti rose petal top high recommend chocol croissant
#
#                                        word_count label
# idx
# idx10  <FreqDist with 10 samples and 11 outcomes>   NaN

# %%
df.loc[(df.BakeryName=="pilot project brewing"), 'label'] = 'not'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
df[df['label'].isnull()]
# Out:
#                                                                                                          BakeryName  \
# idx
# idx0                                                                                hendrickx belgian bread crafter
# idx1                                                                                             lost larson bakery
# idx2                                                                                     bang bang pie and biscuits
# idx4                                                                                        p%C3%A2tisserie coralie
# idx5                                                                                             goddess and grocer
# idx6                                                                                       floriole cafe and bakery
# idx7                                                                                              maison parisienne
# idx8                                                                                             ritual coffeehouse
# idx9         amazing breads and cakes des plaines?hrid=avb0RwCVgMb1u5N2d8G 6A&amp;osq=croissant">more</a></span></p
# idx11                                                                                     lutz cafe and pastry shop
# idx12                                                                                          le caf%C3%A9 station
# idx13                                                                                   the bakery at piccolo mondo
# idx14                     cafe fleurette winnetka?hrid=MA7yRTWtOV3CIF_hMQO4LA&amp;osq=croissant">more</a></span></p
# idx15                                                                                    fairgrounds coffee and tea
# idx16                                                                                      hoosier mama pie company
# idx17                                                                                                 maison marcel
# idx18                                                                                            passion house cafe
# idx19                                                                                        emeche cakery and cafe
# idx20                                                                                      alliance bakery and cafe
# idx21           bakery crescent arlington heights?hrid=BfmrJBVNkkL0KJUenR6GVA&amp;osq=croissant">more</a></span></p
# idx22                                                                                           oromo cafe bucktown
# idx23      kneads and wants artisan bakery skokie?hrid=8yDPP3D8msqNs lxKPvN6A&amp;osq=croissant">more</a></span></p
# idx24                                                                                       coffee lab and roasters
# idx25                                                                                              firecakes donuts
# idx26                                                                  the avondale coffee club by reprise roasters
# idx28                                                                                       bittersweet pastry shop
# idx29                                                                                                      for five
# idx30                                                                                      blue sky bakery and cafe
# idx31                 schlegls bakery lincolnwood?hrid=6C17Nd9qqC8fkZrE2CgKgw&amp;osq=croissant">more</a></span></p
# idx32              turano baking company berwyn 2?hrid=tHu_goKeFPAKptSZhEQc2A&amp;osq=croissant">more</a></span></p
# idx34                                                                                   kristoffers cafe and bakery
# idx35                                                                                               artemios bakery
# idx36      that little french guy highland park 2?hrid=BCbfiWFQ 5nX_e6EhgUg7w&amp;osq=croissant">more</a></span></p
# idx37                                                                                             girl and the goat
# idx38                                                                              la malinche coffee and tea house
# idx40                                                                       chocolate city coffee palace and bodega
# idx41                                                                                           standing passengers
# idx42                                                                                       leonidas chocolate cafe
# idx43                                                                                                      fabcakes
# idx44                                                                                           river valley market
# idx45                         rustic knead lemont?hrid=0wHTICWlJvZQvw_g42HdOw&amp;osq=croissant">more</a></span></p
# idx46                                                                                         bridgeport bakery 2 0
# idx47                                                                                      brew brew coffee and tea
# idx48           beths little bake shop evanston 2?hrid=JKJNqFeSG5XcUORsjdAHEA&amp;osq=croissant">more</a></span></p
# idx49        labriola bakery and cafe oak brook 3?hrid=sBU_ubkwp6G0L6 HiI_R7g&amp;osq=croissant">more</a></span></p
# idx50                                                                                             two hearted queen
# idx51                                                                                           sipping turtle cafe
# idx52                    cafe la fortuna hinsdale?hrid=n4jT2IjbiBwpub5O6zUnXQ&amp;osq=croissant">more</a></span></p
# idx53                                                                                     panader%C3%ADa nuevo leon
# idx54                                                                                             la colombe coffee
# idx55                                                                                         intelligentsia coffee
# idx56                                                                    dark matter coffee electric mud coffee bar
# idx57                                                                                                 dollop coffee
# idx58                                                                                       klein s bakery and cafe
# idx59                                                                                   bittersweet time out market
# idx60        pastry house hippo arlington heights?hrid=SJxb4RcWGVzy1S ZUOYOBQ&amp;osq=croissant">more</a></span></p
# idx61                                                              grounds of being the divinity school coffee shop
# idx62                                                                                                      cocoa co
# idx63        le macaron french pastries oak brook?hrid=eNflilG_Qgx45eAW21uC6w&amp;osq=croissant">more</a></span></p
# idx64                                                                                  astoria caf%C3%A9 and bakery
# idx65       sugar fix%C3%A9 patisserie oak park 2?hrid=jPtl2MyjvYWIdR5gKqwq_g&amp;osq=croissant">more</a></span></p
# idx66                                                                                portage grounds coffee and tea
# idx67          jarosch bakery elk grove village 2?hrid=mgoFwjzrILy8F3SamIUuQw&amp;osq=croissant">more</a></span></p
# idx68                                                                                   groundswell coffee roasters
# idx69                 shalom bakery buffalo grove?hrid=UaBx bhA2f2Ro6ZpaBWgHA&amp;osq=croissant">more</a></span></p
# idx70                                                                             barry callebaut chocolate academy
# idx71           toni patisserie and cafe hinsdale?hrid=UhE_pzXk5RrIWo8frwnuew&amp;osq=croissant">more</a></span></p
# idx72                                                                                    west town bakery and diner
# idx73          talerico martin bakery summit argo?hrid=EjnxtzNssxzzs4F8rJex1A&amp;osq=croissant">more</a></span></p
# idx74                                                                               corridor brewery and provisions
# idx75                                                                                           nhu lan saigon subs
# idx76        leonidas chocolate cafe northbrook 4?hrid=92MNvrBggR2byNEKeqyjFg&amp;osq=croissant">more</a></span></p
# idx77       courageous bakery and cafe oak park 2?hrid=OIWQA6a239HD4jGU1Fg1xw&amp;osq=croissant">more</a></span></p
# idx78                                                                                         beatrix fulton market
# idx79       handsome bakery and cafe schaumburg 3?hrid=DJatIArtQk_V1nzz88WIpQ&amp;osq=croissant">more</a></span></p
# idx80   dolcetti patisserie and cafe park ridge 4?hrid=wgbYXtPqmu4NEaje kWcNA&amp;osq=croissant">more</a></span></p
# idx81                                                                                                tous les jours
# idx82                                                                             dark matter coffee the mothership
# idx83                                                                                   kleins bakery and caf%C3%A9
# idx84             around cafe arlington heights 2?hrid=K6kcp2fdva986eucz6jbZQ&amp;osq=croissant">more</a></span></p
# idx85                blackberry market glen ellyn?hrid=TouCOc_JkWYQ Su4dlbh3Q&amp;osq=croissant">more</a></span></p
# idx86  libanais sweets and restaurant lincolnwood?hrid=o86bvW9jBQp_sVBikCj8hA&amp;osq=croissant">more</a></span></p
# idx87                                                                                  big delicious planet canteen
# idx88                                                                               la catedral cafe and restaurant
# idx89                                                                               heritage bicycles general store
#
#                                                                                                                                                                                                      Review  \
# idx
# idx0                                                                                                The almond chocolate croissant and french country bread were quite authentic and wonderfully rustic.”\n
# idx1                                                                                          These are the best cinnamon rolls ever. The croissant are also delicious and the service is very efficient”\n
# idx2                                                                                                   reminded me of a croissant) and light. The actual filling was very good and you can clearly taste”\n
# idx4                                                       is a croissant desert. Search no more. Very friendly staff, great tea and coffee. A truly welcome addition to the neighborhood. Best of luck.”\n
# idx5                                                                        looking inventory. We came for breakfast and I got the chai latte with oat milk and the croissant sandwich. Fresh and yummy!”\n
# idx6                                                                                                    enjoyable. I also treated myself to an almond croissant (not warmed). It was amazing. Not overly”\n
# idx7   watching them. <span class="css-1egxyvc" data-font-weight="bold">Croissant</span> was awful - stale and lacked even a hint of butter. However the cafe au Latte was very well made and delicious.”\n
# idx8                                                                      recommended a "cortado" which blew me away. Almond croissant and vinyl records - what's not to like? Check it out- it's a gem!”\n
# idx9                                                                                Excellent croissant, delicious crumb cake, and even the made to order panini was very good. I will certainly return.”\n
# idx11                                                                                               croissant. I have to say this was probably the best one I ever had. The dark chocolate was very rich”\n
# idx12                                                                                             is good. I'm a huge fan of croissant. First time I got the strawberry croissant and it was really good”\n
# idx13                                                                                                    What an amazing coffee shop and bakery. Everything is made from scratch. Fresh croissant, fruit”\n
# idx14                                                                                        But it is! The bread is delicious (I get a chocolate croissant), and the owner is so friendly and charming.”\n
# idx15                                                                                              sandwich on croissant and a truffle latte. The kids got a kick out of the breakfast served in a lunch”\n
# idx16                                                                                        and cream admixture and a flaky buttery crust almost like that of a croissant. Indecisive and gluttonous as”\n
# idx17                                                                                        experience both times. Got a croissant and an iced coffee the first time and a blueberry danish and an iced”\n
# idx18                                    So good! I got a lavender which is my drink of choice so I'm always ranking them and this one took the cake. Will definitely be back. As of today, you have to…”\n
# idx19                                                                                       Bronzeville coffees, an apple cider donut, a blueberry muffin, and a turkey bacon, egg, and cheese croissant”\n
# idx20                                                                                              on here to say how amazing the almond croissant is. There is a cute seating area to enjoy your coffee”\n
# idx21                                                                                      was the chocolate croissant. One taste I was hooked. Since I couldn't eat all the pastries in one sitting, it”\n
# idx22                                                                                             and energy in mind. We tried brownies, cookies, croissant, and various iced and hot coffee. What can I”\n
# idx23                                                                                             croissant. The scones were my favorite. And, don't get me going about the desserts, out of this world.”\n
# idx24                                         lavender oat milk latte and croissant ran me about $12 but I think it was def worth it. <span class="css-1egxyvc" data-font-weight="bold">Croissant</span>”\n
# idx25                                                                                           of a croissant or cinnamon-raisin bread more so than a donut. It was decent. Just not my kind of fritter”\n
# idx26                                                                                           selection or syrup flavors and delicious croissant. They have cocktails! And you can add in CBD as well.”\n
# idx28                                       The most lovely one stop shop for bakery goods! <span class="css-1egxyvc" data-font-weight="bold">Croissants</span>, cinnamon rolls, tarts, cupcakes... They”\n
# idx29                                                I had the ham and cheese croissant and was not disappointed. It was incredible, as was the pour over. Will definitely be back when I'm in the area.”\n
# idx30                                  The best part is their transitional program for at-risk young adults. The second best part is that it's just a delicious cafe in general with unique &amp; yummy…”\n
# idx31                                                                                               croissant, coffee cakes, and two pies. Including a key lime pie and a pecan. The croissant were fine”\n
# idx32                                                                                               There are also fresh cookies, cakes and croissant! The staff members are perhaps the NICEST and most”\n
# idx34                                                                                              the breakfast croissant, tamales, and some of the baked goods. The woman who usually takes the orders”\n
# idx35                                                                                         croissant along with a sweet treat. I am so used to most things being so over priced in Lakeview that I am”\n
# idx36                                                                                        Onion soup just ok, croque mousier needed more bechemel. Excellent mini lemon meringue tart! Good croissant”\n
# idx37                                                                                        a croissant had a baby with a brioche and somehow formed itself like a cheesy popover, you could almost get”\n
# idx38                                                                                             and unique seating areas are perfection. We ordered lattes and a dried fruit tea. We added a croissant”\n
# idx40                                                                                                    the Horchata. They also have an awesome selection of bagels, croissant, muffins, scones, donuts”\n
# idx41                                                                                             pastries. The croissant are awesome, and huge! They showcase some cool local art that changes often. I”\n
# idx42                                                                                           water. The almond croissant was soft and crunchy. There are thin almond slices and powdered sugar on top”\n
# idx43                                               all the pastries from scratch every day. I highly recommend going to this small business! By the way the quiche and savory croissant are to die for!”\n
# idx44                                     This is my favorite breakfast place in the city. Everything is well made and delicious. Great quality and beautiful grocery section. Their blueberry cardamom…”\n
# idx45                                                                         Loved the ham and cheese croissant. Service was great despite being extremely busy. Can't wait to go back and try a muffin”\n
# idx46                                          and a ham and cheese croissant. It was around $14. Everything was super yummy. They don't have a parking lot, but I think you may be able to find street…”\n
# idx47                                                                                           croissant is a dream) not to mention a great selection of local coffee beans for sale. I knocked it down”\n
# idx48                                                                                                 ever eaten. I also really enjoy the spinach/feta and ham and cheese scones, three cheese croissant”\n
# idx49                                                                                                 surgery, I am sipping a mocha latte and noshing on a chocolate almond croissant. At first I didn't”\n
# idx50                                                                                          and croissant. You can sit here for hours together. The staff are super friendly, and you can have a nice”\n
# idx51                                                                                           their ham&amp;cheese croissant sandwich, which I can never take a picture of, because I alway eat it too”\n
# idx52                                                   The BEST COFFEE around! Great service, great coffee &amp; croissant! I wouldn't go anywhere else!!! So friendly, they always remember your name!”\n
# idx53                                                                                                but they were nice! I do wish that I asked if my vegan apple pastry or chocolate croissant could be”\n
# idx54                                                                                          the window and 2 benches outsides. The almond croissant was disappointing - no almond taste in my opinion”\n
# idx55                                                                                            the third but it was something unusual and fun as well), + Voss water (so fancy!), and a croissant (one”\n
# idx56                                                                                             croissant. Not sure if I'd recommend it for working as seating is limited and the music is a bit loud.”\n
# idx57                                                                  Ordered latte and chocolate croissant. Both are good. Like their interior design and music too. Staffs are friendly. Will return.”\n
# idx58                                                          and cheese croissant, which is great. Excited to try the other stuff on their menu since everything I've had has been really good so far!”\n
# idx59                                                                                                         These included chocolate croissant, ham and cheese croissant, quiches, baguette sandwiches”\n
# idx60                                                                                              red bean buns, chocolate croissant, and hot dog buns. They also sell cakes as a whole or by the slice”\n
# idx61                                                                                          and very cheap--if you bring your own mug you can get 18 oz of coffee and a croissant for $3.50. The wall”\n
# idx62                                                pumpkin latte was also one of the worst lattes I've ever had in my life. Thank goodness for Megs chocolate croissant though. Only reason to return!”\n
# idx63                                                                                                  Strangest experience ever. When we arrived we were told croissant were still in oven and it would”\n
# idx64                                                                                                     The pitas are delicious. It's like a buttery croissant with cheese filling. The bread is crisp”\n
# idx65                                                                                                     Awesome local place. I just had the BEST chocolate croissant of my LIFE. Kind workers and even”\n
# idx66                                                                                            seating, with a fireplace for cooler winter days. Extensive pastries (think scones, croissant, kolaches”\n
# idx67                                                  is also fun. Lest you think they're all about sweets, I'll recommend the croissant and potato bread. Try it for a hearty sandwich or for dipping.”\n
# idx68                                                                                                    and chai tea latte w/ almond milk, and sometimes a delicious pastry or ham and cheese croissant”\n
# idx69                              <span class="css-1egxyvc" data-font-weight="bold">Croissants</span> were out of this world!!! Drove there from Schaumburg and won't ever think twice about the drive!”\n
# idx70                                   World class instructors teach the classes here. They often bring chefs in from outside the academy (even from other countries) to teach as well, if they have a…”\n
# idx71                                                                                     Cold small coffee and a croissant for eight bucks!? I would not make this my regular place for morning coffee.”\n
# idx72                                                                                                amazing - and the blueberry crumble donut was probably the best I've had . The croissant which held”\n
# idx73                                   Talerico-Martin is the quiet secret, right outside of Chicago on West 63rd St. The doughnuts, danishes, fritters are the best I've had. Made freshly all day, I…”\n
# idx74                                                                                                 and a croissant with jam. It was just enough without feeling bloated. My bae decided to relive his”\n
# idx75                                                                                             croissant, among other delectable things. But there was a minor flaw in their recipe. They tasted like”\n
# idx76                                                                                                    for me. My orange scone was raw in the middle and not that flavorful and my daughters croissant”\n
# idx77                                                                                                     place... Highlight of my most recent visit was the almond croissant. It tastes like a cake, so”\n
# idx78                                                                                                   croissant and what a great way to start the day! Not all croissant are made equally and this one”\n
# idx79                                                                                                were various croissant, castella, large cookies and Pain Au Chocolat to name a few. They have quite”\n
# idx80                                                                                                  an assortment of macaroons as a hostess gift and an almond croissant. Both were out of this world”\n
# idx81                                                                                    the croissant are a bit dry and you really need that coffee or tea to pair them with. There are no posted hours”\n
# idx82                                                                                      with caffeine which I need it before going into work. I also got the croissant just because I have a weakness”\n
# idx83                                                                                                energy that walked in. The coffee was fantastic and the croissant they made were soft and flavorful”\n
# idx84                                                                                              latte. The crawffles (croissant+waffle) were delicious and the sheep macarons are tasty and adorable!”\n
# idx85                                                             good. Top-notch veggie breakfast sandwich and an expertly baked chocolate croissant. The blackberry oatmeal remains a favorite. Bravo!”\n
# idx86                                                                                            chocolate croissant on the north side. Their lattes are like being in Europe. If you are a lover of all”\n
# idx87                                                                                           croissant sized for Goldy Locks, bagel sandwiches, mac and cheese, and a damned good "strong enough" cup”\n
# idx88                                                                                                    The turkey sausage eqq croissant my girl says was awesome. She really enjoyed the refried beans”\n
# idx89                                                                                          are higher than average - 16oz iced coffee is $5. Almond croissant is $4.50. I've felt surprised a couple”\n
#
#                                                                                                                                                                                                                              Review_Prepped  \
# idx
# idx0                                                                                                                                 ['almond', 'chocol', 'croissant', 'french', 'countri', 'bread', 'quit', 'authent', 'wonder', 'rustic']
# idx1                                                                                                                                                ['best', 'cinnamon', 'roll', 'ever', 'croissant', 'also', 'delici', 'servic', 'effici']
# idx2                                                                                                                                                            ['remind', 'croissant', 'light', 'actual', 'fill', 'good', 'clear', 'tast']
# idx4                                                                                              ['croissant', 'desert', 'search', 'friend', 'staff', 'great', 'tea', 'coffe', 'truli', 'welcom', 'addit', 'neighborhood', 'best', 'luck']
# idx5                                                                                                            ['look', 'inventori', 'came', 'breakfast', 'got', 'chai', 'latt', 'oat', 'milk', 'croissant', 'sandwich', 'fresh', 'yummi']
# idx6                                                                                                                                                              ['enjoy', 'also', 'treat', 'almond', 'croissant', 'warm', 'amaz', 'over']
# idx7   ['watch', 'span', 'class', '="', 'css', '1egxyvc', 'data', 'font', 'weight', '="', 'bold', 'croissant', '</', 'span', '>', 'aw', 'stale', 'lack', 'even', 'hint', 'butter', 'howev', 'cafe', 'au', 'latt', 'well', 'made', 'delici']
# idx8                                                                                                                        ['recommend', 'cortado', 'blew', 'away', 'almond', 'croissant', 'vinyl', 'record', 'like', '?', 'check', 'gem']
# idx9                                                                                                                      ['excel', 'croissant', 'delici', 'crumb', 'cake', 'even', 'made', 'order', 'panini', 'good', 'certain', 'return']
# idx11                                                                                                                                                      ['croissant', 'say', 'probabl', 'best', 'one', 'ever', 'dark', 'chocol', 'rich']
# idx12                                                                                                                             ['good', 'huge', 'fan', 'croissant', 'first', 'time', 'got', 'strawberri', 'croissant', 'realli', 'good']
# idx13                                                                                                                                      ['amaz', 'coffe', 'shop', 'bakeri', 'everyth', 'made', 'scratch', 'fresh', 'croissant', 'fruit']
# idx14                                                                                                                                                         ['bread', 'delici', 'get', 'chocol', 'croissant', 'owner', 'friend', 'charm']
# idx15                                                                                                                                       ['sandwich', 'croissant', 'truffl', 'latt', 'kid', 'got', 'kick', 'breakfast', 'serv', 'lunch']
# idx16                                                                                                                               ['cream', 'admixtur', 'flaki', 'butteri', 'crust', 'almost', 'like', 'croissant', 'indecis', 'glutton']
# idx17                                                                                                                                 ['experi', 'time', 'got', 'croissant', 'ice', 'coffe', 'first', 'time', 'blueberri', 'danish', 'ice']
# idx18                                                                                                                 ['good', 'got', 'lavend', 'drink', 'choic', 'alway', 'rank', 'one', 'took', 'cake', 'definit', 'back', 'today', '…”']
# idx19                                                                                                              ['bronzevill', 'coffe', 'appl', 'cider', 'donut', 'blueberri', 'muffin', 'turkey', 'bacon', 'egg', 'chees', 'croissant']
# idx20                                                                                                                                                      ['say', 'amaz', 'almond', 'croissant', 'cute', 'seat', 'area', 'enjoy', 'coffe']
# idx21                                                                                                                                                 ['chocol', 'croissant', 'one', 'tast', 'hook', 'sinc', 'eat', 'pastri', 'one', 'sit']
# idx22                                                                                                                                           ['energi', 'mind', 'tri', 'browni', 'cooki', 'croissant', 'various', 'ice', 'hot', 'coffe']
# idx23                                                                                                                                                                    ['croissant', 'scone', 'favorit', 'get', 'go', 'dessert', 'world']
# idx24                           ['lavend', 'oat', 'milk', 'latt', 'croissant', 'ran', '$', '12', 'think', 'def', 'worth', 'span', 'class', '="', 'css', '1egxyvc', 'data', 'font', 'weight', '="', 'bold', 'croissant', '</', 'span', '>”']
# idx25                                                                                                                                                    ['croissant', 'cinnamon', 'raisin', 'bread', 'donut', 'decent', 'kind', 'fritter']
# idx26                                                                                                                                                ['select', 'syrup', 'flavor', 'delici', 'croissant', 'cocktail', 'add', 'cbd', 'well']
# idx28                             ['love', 'one', 'stop', 'shop', 'bakeri', 'good', 'span', 'class', '="', 'css', '1egxyvc', 'data', 'font', 'weight', '="', 'bold', 'croissant', '</', 'span', '>,', 'cinnamon', 'roll', 'tart', 'cupcak']
# idx29                                                                                                                                              ['ham', 'chees', 'croissant', 'disappoint', 'incred', 'pour', 'definit', 'back', 'area']
# idx30                                                                           ['best', 'part', 'transit', 'program', 'risk', 'young', 'adult', 'second', 'best', 'part', 'delici', 'cafe', 'general', 'uniqu', 'amp', ';', 'yummi', '…”']
# idx31                                                                                                                            ['croissant', 'coffe', 'cake', 'two', 'pie', 'includ', 'key', 'lime', 'pie', 'pecan', 'croissant', 'fine']
# idx32                                                                                                                                                ['also', 'fresh', 'cooki', 'cake', 'croissant', 'staff', 'member', 'perhap', 'nicest']
# idx34                                                                                                                                                ['breakfast', 'croissant', 'tamal', 'bake', 'good', 'woman', 'usual', 'take', 'order']
# idx35                                                                                                                                                         ['croissant', 'along', 'sweet', 'treat', 'use', 'thing', 'price', 'lakeview']
# idx36                                                                                                     ['onion', 'soup', 'ok', 'croqu', 'mousier', 'need', 'bechemel', 'excel', 'mini', 'lemon', 'meringu', 'tart', 'good', 'croissant']
# idx37                                                                                                                               ['croissant', 'babi', 'brioch', 'somehow', 'form', 'like', 'cheesi', 'popov', 'could', 'almost', 'get']
# idx38                                                                                                                                       ['uniqu', 'seat', 'area', 'perfect', 'order', 'latt', 'dri', 'fruit', 'tea', 'ad', 'croissant']
# idx40                                                                                                                                            ['horchata', 'also', 'awesom', 'select', 'bagel', 'croissant', 'muffin', 'scone', 'donut']
# idx41                                                                                                                                        ['pastri', 'croissant', 'awesom', 'huge', 'showcas', 'cool', 'local', 'art', 'chang', 'often']
# idx42                                                                                                                              ['water', 'almond', 'croissant', 'soft', 'crunchi', 'thin', 'almond', 'slice', 'powder', 'sugar', 'top']
# idx43                                                                                                       ['pastri', 'scratch', 'everi', 'day', 'high', 'recommend', 'go', 'small', 'busi', 'way', 'quich', 'savori', 'croissant', 'die']
# idx44                                                                     ['favorit', 'breakfast', 'place', 'citi', 'everyth', 'well', 'made', 'delici', 'great', 'qualiti', 'beauti', 'groceri', 'section', 'blueberri', 'cardamom', '…”']
# idx45                                                                                                           ['love', 'ham', 'chees', 'croissant', 'servic', 'great', 'despit', 'extrem', 'busi', 'wait', 'go', 'back', 'tri', 'muffin']
# idx46                                                                                         ['ham', 'chees', 'croissant', 'around', '$', '14', 'everyth', 'super', 'yummi', 'park', 'lot', 'think', 'may', 'abl', 'find', 'street', '…”']
# idx47                                                                                                                                       ['croissant', 'dream', 'mention', 'great', 'select', 'local', 'coffe', 'bean', 'sale', 'knock']
# idx48                                                                                                               ['ever', 'eaten', 'also', 'realli', 'enjoy', 'spinach', 'feta', 'ham', 'chees', 'scone', 'three', 'chees', 'croissant']
# idx49                                                                                                                                                 ['surgeri', 'sip', 'mocha', 'latt', 'nosh', 'chocol', 'almond', 'croissant', 'first']
# idx50                                                                                                                                                            ['croissant', 'sit', 'hour', 'togeth', 'staff', 'super', 'friend', 'nice']
# idx51                                                                                                                                      ['ham', 'amp', ';', 'chees', 'croissant', 'sandwich', 'never', 'take', 'pictur', 'alway', 'eat']
# idx52                                                                                ['best', 'coffe', 'around', 'great', 'servic', 'great', 'coffe', 'amp', ';', 'croissant', 'go', 'anywher', 'els', 'friend', 'alway', 'rememb', 'name']
# idx53                                                                                                                                                    ['nice', 'wish', 'ask', 'vegan', 'appl', 'pastri', 'chocol', 'croissant', 'could']
# idx54                                                                                                                                  ['window', '2', 'bench', 'outsid', 'almond', 'croissant', 'disappoint', 'almond', 'tast', 'opinion']
# idx55                                                                                                                                             ['third', 'someth', 'unusu', 'fun', 'well', 'voss', 'water', 'fanci', 'croissant', 'one']
# idx56                                                                                                                                                   ['croissant', 'sure', 'recommend', 'work', 'seat', 'limit', 'music', 'bit', 'loud']
# idx57                                                                                                                  ['order', 'latt', 'chocol', 'croissant', 'good', 'like', 'interior', 'design', 'music', 'staff', 'friend', 'return']
# idx58                                                                                                                          ['chees', 'croissant', 'great', 'excit', 'tri', 'stuff', 'menu', 'sinc', 'everyth', 'realli', 'good', 'far']
# idx59                                                                                                                                        ['includ', 'chocol', 'croissant', 'ham', 'chees', 'croissant', 'quich', 'baguett', 'sandwich']
# idx60                                                                                                                          ['red', 'bean', 'bun', 'chocol', 'croissant', 'hot', 'dog', 'bun', 'also', 'sell', 'cake', 'whole', 'slice']
# idx61                                                                                                                                            ['cheap', 'bring', 'mug', 'get', '18', 'oz', 'coffe', 'croissant', '$', '3', '50', 'wall']
# idx62                                                                                      ['pumpkin', 'latt', 'also', 'one', 'worst', 'latt', 'ever', 'life', 'thank', 'good', 'meg', 'chocol', 'croissant', 'though', 'reason', 'return']
# idx63                                                                                                                                               ['strangest', 'experi', 'ever', 'arriv', 'told', 'croissant', 'still', 'oven', 'would']
# idx64                                                                                                                                                 ['pita', 'delici', 'like', 'butteri', 'croissant', 'chees', 'fill', 'bread', 'crisp']
# idx65                                                                                                                                         ['awesom', 'local', 'place', 'best', 'chocol', 'croissant', 'life', 'kind', 'worker', 'even']
# idx66                                                                                                                          ['seat', 'fireplac', 'cooler', 'winter', 'day', 'extens', 'pastri', 'think', 'scone', 'croissant', 'kolach']
# idx67                                                                                                            ['also', 'fun', 'lest', 'think', 'sweet', 'recommend', 'croissant', 'potato', 'bread', 'tri', 'hearti', 'sandwich', 'dip']
# idx68                                                                                                                            ['chai', 'tea', 'latt', 'w', 'almond', 'milk', 'sometim', 'delici', 'pastri', 'ham', 'chees', 'croissant']
# idx69                                                  ['span', 'class', '="', 'css', '1egxyvc', 'data', 'font', 'weight', '="', 'bold', 'croissant', '</', 'span', '>', 'world', 'drove', 'schaumburg', 'ever', 'think', 'twice', 'drive']
# idx70                                                                                           ['world', 'class', 'instructor', 'teach', 'class', 'often', 'bring', 'chef', 'outsid', 'academi', 'even', 'countri', 'teach', 'well', '…”']
# idx71                                                                                                                        ['cold', 'small', 'coffe', 'croissant', 'eight', 'buck', 'would', 'make', 'regular', 'place', 'morn', 'coffe']
# idx72                                                                                                                                                      ['amaz', 'blueberri', 'crumbl', 'donut', 'probabl', 'best', 'croissant', 'held']
# idx73                                                                  ['talerico', 'martin', 'quiet', 'secret', 'right', 'outsid', 'chicago', 'west', '63rd', 'st', 'doughnut', 'danish', 'fritter', 'best', 'made', 'fresh', 'day', '…”']
# idx74                                                                                                                                                   ['croissant', 'jam', 'enough', 'without', 'feel', 'bloat', 'bae', 'decid', 'reliv']
# idx75                                                                                                                                                   ['croissant', 'among', 'delect', 'thing', 'minor', 'flaw', 'recip', 'tast', 'like']
# idx76                                                                                                                                                                 ['orang', 'scone', 'raw', 'middl', 'flavor', 'daughter', 'croissant']
# idx77                                                                                                                                              ['place', 'highlight', 'recent', 'visit', 'almond', 'croissant', 'tast', 'like', 'cake']
# idx78                                                                                                                                                    ['croissant', 'great', 'way', 'start', 'day', 'croissant', 'made', 'equal', 'one']
# idx79                                                                                                                                       ['various', 'croissant', 'castella', 'larg', 'cooki', 'pain', 'au', 'chocolat', 'name', 'quit']
# idx80                                                                                                                                                             ['assort', 'macaroon', 'hostess', 'gift', 'almond', 'croissant', 'world']
# idx81                                                                                                                                                 ['croissant', 'bit', 'dri', 'realli', 'need', 'coffe', 'tea', 'pair', 'post', 'hour']
# idx82                                                                                                                                                                 ['caffein', 'need', 'go', 'work', 'also', 'got', 'croissant', 'weak']
# idx83                                                                                                                                                         ['energi', 'walk', 'coffe', 'fantast', 'croissant', 'made', 'soft', 'flavor']
# idx84                                                                                                                                              ['latt', 'crawffl', 'croissant', 'waffl', 'delici', 'sheep', 'macaron', 'tasti', 'ador']
# ...
# idx16                                                                         cream admixtur flaki butteri crust almost like croissant indecis glutton
# idx17                                                                              experi time got croissant ice coffe first time blueberri danish ice
# idx18                                                                       good got lavend drink choic alway rank one took cake definit back today …”
# idx19                                                              bronzevill coffe appl cider donut blueberri muffin turkey bacon egg chees croissant
# idx20                                                                                             say amaz almond croissant cute seat area enjoy coffe
# idx21                                                                                           chocol croissant one tast hook sinc eat pastri one sit
# idx22                                                                                     energi mind tri browni cooki croissant various ice hot coffe
# idx23                                                                                                     croissant scone favorit get go dessert world
# idx24                  lavend oat milk latt croissant ran $ 12 think def worth span class =" css 1egxyvc data font weight =" bold croissant </ span >”
# idx25                                                                                        croissant cinnamon raisin bread donut decent kind fritter
# idx26                                                                                       select syrup flavor delici croissant cocktail add cbd well
# idx28                 love one stop shop bakeri good span class =" css 1egxyvc data font weight =" bold croissant </ span >, cinnamon roll tart cupcak
# idx29                                                                                     ham chees croissant disappoint incred pour definit back area
# idx30                                             best part transit program risk young adult second best part delici cafe general uniqu amp ; yummi …”
# idx31                                                                            croissant coffe cake two pie includ key lime pie pecan croissant fine
# idx32                                                                                       also fresh cooki cake croissant staff member perhap nicest
# idx34                                                                                       breakfast croissant tamal bake good woman usual take order
# idx35                                                                                             croissant along sweet treat use thing price lakeview
# idx36                                                           onion soup ok croqu mousier need bechemel excel mini lemon meringu tart good croissant
# idx37                                                                            croissant babi brioch somehow form like cheesi popov could almost get
# idx38                                                                                    uniqu seat area perfect order latt dri fruit tea ad croissant
# idx40                                                                                   horchata also awesom select bagel croissant muffin scone donut
# idx41                                                                                  pastri croissant awesom huge showcas cool local art chang often
# idx42                                                                           water almond croissant soft crunchi thin almond slice powder sugar top
# idx43                                                             pastri scratch everi day high recommend go small busi way quich savori croissant die
# idx44                                 favorit breakfast place citi everyth well made delici great qualiti beauti groceri section blueberri cardamom …”
# idx45                                                                 love ham chees croissant servic great despit extrem busi wait go back tri muffin
# idx46                                                        ham chees croissant around $ 14 everyth super yummi park lot think may abl find street …”
# idx47                                                                                 croissant dream mention great select local coffe bean sale knock
# idx48                                                                  ever eaten also realli enjoy spinach feta ham chees scone three chees croissant
# idx49                                                                                        surgeri sip mocha latt nosh chocol almond croissant first
# idx50                                                                                                croissant sit hour togeth staff super friend nice
# idx51                                                                                   ham amp ; chees croissant sandwich never take pictur alway eat
# idx52                                               best coffe around great servic great coffe amp ; croissant go anywher els friend alway rememb name
# idx53                                                                                           nice wish ask vegan appl pastri chocol croissant could
# idx54                                                                            window 2 bench outsid almond croissant disappoint almond tast opinion
# idx55                                                                                       third someth unusu fun well voss water fanci croissant one
# idx56                                                                                          croissant sure recommend work seat limit music bit loud
# idx57                                                                  order latt chocol croissant good like interior design music staff friend return
# idx58                                                                          chees croissant great excit tri stuff menu sinc everyth realli good far
# idx59                                                                               includ chocol croissant ham chees croissant quich baguett sandwich
# idx60                                                                             red bean bun chocol croissant hot dog bun also sell cake whole slice
# idx61                                                                                            cheap bring mug get 18 oz coffe croissant $ 3 50 wall
# idx62                                                  pumpkin latt also one worst latt ever life thank good meg chocol croissant though reason return
# idx63                                                                                      strangest experi ever arriv told croissant still oven would
# idx64                                                                                        pita delici like butteri croissant chees fill bread crisp
# idx65                                                                                   awesom local place best chocol croissant life kind worker even
# idx66                                                                       seat fireplac cooler winter day extens pastri think scone croissant kolach
# idx67                                                               also fun lest think sweet recommend croissant potato bread tri hearti sandwich dip
# idx68                                                                            chai tea latt w almond milk sometim delici pastri ham chees croissant
# idx69                             span class =" css 1egxyvc data font weight =" bold croissant </ span > world drove schaumburg ever think twice drive
# idx70                                                    world class instructor teach class often bring chef outsid academi even countri teach well …”
# idx71                                                                        cold small coffe croissant eight buck would make regular place morn coffe
# idx72                                                                                          amaz blueberri crumbl donut probabl best croissant held
# idx73                                    talerico martin quiet secret right outsid chicago west 63rd st doughnut danish fritter best made fresh day …”
# idx74                                                                                          croissant jam enough without feel bloat bae decid reliv
# idx75                                                                                          croissant among delect thing minor flaw recip tast like
# idx76                                                                                                  orang scone raw middl flavor daughter croissant
# idx77                                                                                     place highlight recent visit almond croissant tast like cake
# idx78                                                                                           croissant great way start day croissant made equal one
# idx79                                                                                 various croissant castella larg cooki pain au chocolat name quit
# idx80                                                                                              assort macaroon hostess gift almond croissant world
# idx81                                                                                           croissant bit dri realli need coffe tea pair post hour
# idx82                                                                                                     caffein need go work also got croissant weak
# idx83                                                                                             energi walk coffe fantast croissant made soft flavor
# idx84                                                                                     latt crawffl croissant waffl delici sheep macaron tasti ador
# idx85                                     good top notch veggi breakfast sandwich expert bake chocol croissant blackberri oatmeal remain favorit bravo
# idx86                                                                                                chocol croissant north side latt like europ lover
# idx87                                                                   croissant size goldi lock bagel sandwich mac chees damn good strong enough cup
# idx88                                                                              turkey sausag eqq croissant girl say awesom realli enjoy refri bean
# idx89                                                                      higher averag 16oz ice coffe $ 5 almond croissant $ 4 50 felt surpris coupl
#
#                                        word_count label
# idx
# idx0   <FreqDist with 10 samples and 10 outcomes>   NaN
# idx1     <FreqDist with 9 samples and 9 outcomes>   NaN
# idx2     <FreqDist with 8 samples and 8 outcomes>   NaN
# idx4   <FreqDist with 14 samples and 14 outcomes>   NaN
# idx5   <FreqDist with 13 samples and 13 outcomes>   NaN
# idx6     <FreqDist with 8 samples and 8 outcomes>   NaN
# idx7   <FreqDist with 28 samples and 31 outcomes>   NaN
# idx8   <FreqDist with 12 samples and 12 outcomes>   NaN
# idx9   <FreqDist with 12 samples and 12 outcomes>   NaN
# idx11    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx12   <FreqDist with 9 samples and 11 outcomes>   NaN
# idx13  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx14    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx15  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx16  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx17   <FreqDist with 9 samples and 11 outcomes>   NaN
# idx18  <FreqDist with 15 samples and 15 outcomes>   NaN
# idx19  <FreqDist with 12 samples and 12 outcomes>   NaN
# idx20    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx21   <FreqDist with 9 samples and 10 outcomes>   NaN
# idx22  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx23    <FreqDist with 7 samples and 7 outcomes>   NaN
# idx24  <FreqDist with 25 samples and 29 outcomes>   NaN
# idx25    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx26    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx28  <FreqDist with 25 samples and 28 outcomes>   NaN
# idx29    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx30  <FreqDist with 17 samples and 19 outcomes>   NaN
# idx31  <FreqDist with 10 samples and 12 outcomes>   NaN
# idx32    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx34    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx35    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx36  <FreqDist with 14 samples and 14 outcomes>   NaN
# idx37  <FreqDist with 11 samples and 11 outcomes>   NaN
# idx38  <FreqDist with 11 samples and 11 outcomes>   NaN
# idx40    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx41  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx42  <FreqDist with 10 samples and 11 outcomes>   NaN
# idx43  <FreqDist with 14 samples and 14 outcomes>   NaN
# idx44  <FreqDist with 17 samples and 17 outcomes>   NaN
# idx45  <FreqDist with 14 samples and 14 outcomes>   NaN
# idx46  <FreqDist with 18 samples and 18 outcomes>   NaN
# idx47  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx48  <FreqDist with 12 samples and 13 outcomes>   NaN
# idx49    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx50    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx51  <FreqDist with 11 samples and 11 outcomes>   NaN
# idx52  <FreqDist with 15 samples and 17 outcomes>   NaN
# idx53    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx54   <FreqDist with 9 samples and 10 outcomes>   NaN
# idx55  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx56    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx57  <FreqDist with 12 samples and 12 outcomes>   NaN
# idx58  <FreqDist with 12 samples and 12 outcomes>   NaN
# idx59    <FreqDist with 8 samples and 9 outcomes>   NaN
# idx60  <FreqDist with 12 samples and 13 outcomes>   NaN
# idx61  <FreqDist with 12 samples and 12 outcomes>   NaN
# idx62  <FreqDist with 15 samples and 16 outcomes>   NaN
# idx63    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx64    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx65  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx66  <FreqDist with 11 samples and 11 outcomes>   NaN
# idx67  <FreqDist with 13 samples and 13 outcomes>   NaN
# idx68  <FreqDist with 12 samples and 12 outcomes>   NaN
# idx69  <FreqDist with 21 samples and 24 outcomes>   NaN
# idx70  <FreqDist with 14 samples and 16 outcomes>   NaN
# idx71  <FreqDist with 11 samples and 12 outcomes>   NaN
# idx72    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx73  <FreqDist with 19 samples and 19 outcomes>   NaN
# idx74    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx75    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx76    <FreqDist with 7 samples and 7 outcomes>   NaN
# idx77    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx78    <FreqDist with 8 samples and 9 outcomes>   NaN
# idx79  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx80    <FreqDist with 7 samples and 7 outcomes>   NaN
# idx81  <FreqDist with 10 samples and 10 outcomes>   NaN
# idx82    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx83    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx84    <FreqDist with 9 samples and 9 outcomes>   NaN
# idx85  <FreqDist with 15 samples and 15 outcomes>   NaN
# idx86    <FreqDist with 8 samples and 8 outcomes>   NaN
# idx87  <FreqDist with 13 samples and 13 outcomes>   NaN
# idx88  <FreqDist with 11 samples and 11 outcomes>   NaN
# idx89  <FreqDist with 14 samples and 15 outcomes>   NaN

# %%
artisans = ['idx0', 'idx1', 'idx4', 'idx11', 'idx13', 'idx20',\
            'idx22', 'idx26', 'idx36', 'idx42', 'idx43', 'idx47', \
            'idx52', 'idx65', 'idx69', 'idx80', 'idx86', 'idx3', \
            'idx27', 'idx33', 'idx39', 'idx41']

maybes = ['idx6', 'idx8', 'idx9', 'idx12', 'idx14', 'idx19', 'idx24', \
         'idx28', 'idx29', 'idx32', 'idx34', 'idx45', 'idx46', \
         'idx48', 'idx51', 'idx59', 'idx62', 'idx66', 'idx67', \
         'idx72', 'idx74', 'idx77', 'idx78', 'idx79', 'idx83', \
         'idx85', 'idx87']

nots = ['idx2', 'idx5', 'idx7', 'idx15', 'idx16', 'idx17', 'idx21', \
        'idx23', 'idx25', 'idx31', 'idx35', 'idx37', 'idx38', \
        'idx40', 'idx50', 'idx49', 'idx53', 'idx54', 'idx55',\
        'idx56', 'idx57', 'idx58', 'idx60', 'idx61', 'idx63',\
        'idx68', 'idx71', 'idx75', 'idx76', 'idx81', 'idx82',\
        'idx84', 'idx88', 'idx89', 'idx10']

drops_question_mark = ['idx18', 'idx30', 'idx44', 'idx64',\
                       'idx70', 'idx73']

# %% [markdown]
# labeling guideline. . .and stream of consciousness
#
# it is an artisan if it has words like flaky, best ever, like in europe,
# or like
#
# it is a maybe if someone mentions it in a positive way but thats it
# or if they just mention it without any adjectives.. i guess theyre mentioning it.
# or if they're excited about a non-pure croissant i.e. chocolate, ham&cheese, almond,
# or if it's like 'breakfast croissant' or 'croissant sandwich'
# or if it's in like, berwyn (need to think of how to incorporate into model
# possible i cant since yelp banned me :| )
# meanwhile:'best chocolate croissant of my life' with life in caps means it's artisan
#
# it is a no if it is obviously uninteresting. ex. 'the croissant was fine'
# or even if it's neutral, as in it seems like it was just what the
# customer ordered and talked about it and yelped it because they're avid
# yelpers or whatever. or if 'vegan' or if it's a chain or dark matter
# or just a cheese croissant (too easy).
# or if they also talk about hot dogs. you know?
#
# its a drop if it doesnt say anything about croissant at all (expecting 5,
# not sure what happened there)
#
# what to do with these : if it's a mentioning of a croissant but comparing what
# they're actually reviewing with it
#
# ...do we feed these to the machine ?! or will it just get confused :/
#
# self supervised learning seems to be something where you contradict yourself
# i wonder if machines can do that
# weights on the rules. point system, then divide at the end based on point rules

# %%
print('assigning {} artisans . . .'.format(len(artisans)))

# assign
df.loc[artisans,'label'] = 'artisan'

# validate
len(artisans)==df.loc[artisans].shape[0]
# Out:
# assigning 22 artisans . . .
# True

# %%
print('assigning {} nots'.format(len(nots)))

# assign
df.loc[nots,'label'] = 'not'

# validate
len(nots)==df.loc[nots].shape[0]
# Out:
# assigning 35 nots
# True

# %%
print('assigning {} maybes'.format(len(maybes)))

# assign
df.loc[maybes,'label'] = 'maybe'

# validate
len(maybes)==df.loc[maybes].shape[0]
# Out:
# assigning 27 maybes
# True

# %%
print(len(artisans)+len(nots)+len(maybes))
# Out:
# 84

# %%
df[df['label'].isnull()].shape[0]
# Out:
# 6

# %%
print('assigning {} more nots'.format(len(drops_question_mark)))

# assign
df.loc[drops_question_mark,'label'] = 'not'

# validate
len(drops_question_mark)==df.loc[drops_question_mark].shape[0]
# Out:
# assigning 6 more nots
# True

# %%
df[df['label'].isnull()].shape[0]==0
# Out:
# True

# %%
df.to_csv("labeled_croissants.csv")

# %%
df.loc[artisans,].BakeryName
# Out:
# idx
# idx0                                                                                  hendrickx belgian bread crafter
# idx1                                                                                               lost larson bakery
# idx4                                                                                          p%C3%A2tisserie coralie
# idx11                                                                                       lutz cafe and pastry shop
# idx13                                                                                     the bakery at piccolo mondo
# idx20                                                                                        alliance bakery and cafe
# idx22                                                                                             oromo cafe bucktown
# idx26                                                                    the avondale coffee club by reprise roasters
# idx36        that little french guy highland park 2?hrid=BCbfiWFQ 5nX_e6EhgUg7w&amp;osq=croissant">more</a></span></p
# idx42                                                                                         leonidas chocolate cafe
# idx43                                                                                                        fabcakes
# idx47                                                                                        brew brew coffee and tea
# idx52                      cafe la fortuna hinsdale?hrid=n4jT2IjbiBwpub5O6zUnXQ&amp;osq=croissant">more</a></span></p
# idx65         sugar fix%C3%A9 patisserie oak park 2?hrid=jPtl2MyjvYWIdR5gKqwq_g&amp;osq=croissant">more</a></span></p
# idx69                   shalom bakery buffalo grove?hrid=UaBx bhA2f2Ro6ZpaBWgHA&amp;osq=croissant">more</a></span></p
# idx80     dolcetti patisserie and cafe park ridge 4?hrid=wgbYXtPqmu4NEaje kWcNA&amp;osq=croissant">more</a></span></p
# idx86    libanais sweets and restaurant lincolnwood?hrid=o86bvW9jBQp_sVBikCj8hA&amp;osq=croissant">more</a></span></p
# idx3                                                                                                      good ambler
# idx27                                                                                       plein air cafe and eatery
# idx33                                                                                                    caffe umbria
# idx39                  abc bakery and deli norridge?hrid=SDxAypM6HgjzV47KHlp0TQ&amp;osq=croissant">more</a></span></p
# idx41                                                                                             standing passengers
# Name: BakeryName, dtype: object
