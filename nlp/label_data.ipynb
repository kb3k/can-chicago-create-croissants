# %%
import pandas as pd

# %%
df = pd.read_csv("unlabeled_df.csv")

# %%
df.head()
# Out:
#   index                       BakeryName  \
# 0  idx0  hendrickx belgian bread crafter
# 1  idx1               lost larson bakery
# 2  idx2       bang bang pie and biscuits
# 3  idx3                      good ambler
# 4  idx4          p%C3%A2tisserie coralie
#
#                                               Review  \
# 0  The almond chocolate croissant and french coun...
# 1  These are the best cinnamon rolls ever. The cr...
# 2  reminded me of a croissant) and light. The act...
# 3  minutes. - Ham and cheese croissant: croissant...
# 4  is a croissant desert. Search no more. Very fr...
#
#                                       Review_Prepped  \
# 0  ['almond', 'chocol', 'croissant', 'french', 'c...
# 1  ['best', 'cinnamon', 'roll', 'ever', 'croissan...
# 2  ['remind', 'croissant', 'light', 'actual', 'fi...
# 3  ['minut', 'ham', 'chees', 'croissant', ':', 'c...
# 4  ['croissant', 'desert', 'search', 'friend', 's...
#
#                                   Review_Prepped_str  \
# 0  almond chocol croissant french countri bread q...
# 1  best cinnamon roll ever croissant also delici ...
# 2  remind croissant light actual fill good clear ...
# 3  minut ham chees croissant : croissant super fl...
# 4  croissant desert search friend staff great tea...
#
#                                    word_count  label
# 0  <FreqDist with 10 samples and 10 outcomes>    NaN
# 1    <FreqDist with 9 samples and 9 outcomes>    NaN
# 2    <FreqDist with 8 samples and 8 outcomes>    NaN
# 3  <FreqDist with 11 samples and 12 outcomes>    NaN
# 4  <FreqDist with 14 samples and 14 outcomes>    NaN

# %%
df.loc[(df.Review_Prepped_str.str.contains('flak')) & (df.BakeryName!='hoosier mama pie company'), 'label'] = 'artisan'

# %%
df[df.label=='artisan']
# Out:
#     index                                         BakeryName  \
# 3    idx3                                        good ambler
# 27  idx27                          plein air cafe and eatery
# 33  idx33                                       caffe umbria
# 39  idx39  abc bakery and deli norridge?hrid=SDxAypM6Hgjz...
#
#                                                Review  \
# 3   minutes. - Ham and cheese croissant: croissant...
# 27  for more. Pistachio Hazelnut Danish - 4.5/5. F...
# 33  are the highlight of the show, you absolutely ...
# 39  of the seductive sweets. I chose a nutella cro...
#
#                                        Review_Prepped  \
# 3   ['minut', 'ham', 'chees', 'croissant', ':', 'c...
# 27  ['pistachio', 'hazelnut', 'danish', '4', '5', ...
# 33  ['highlight', 'show', 'absolut', 'get', 'crois...
# 39  ['seduct', 'sweet', 'chose', 'nutella', 'crois...
#
#                                    Review_Prepped_str  \
# 3   minut ham chees croissant : croissant super fl...
# 27  pistachio hazelnut danish 4 5 5 flaki croissan...
# 33  highlight show absolut get croissant flaki but...
# 39  seduct sweet chose nutella croissant fluffi fl...
#
#                                     word_count    label
# 3   <FreqDist with 11 samples and 12 outcomes>  artisan
# 27  <FreqDist with 12 samples and 13 outcomes>  artisan
# 33  <FreqDist with 12 samples and 12 outcomes>  artisan
# 39  <FreqDist with 12 samples and 12 outcomes>  artisan
